# %%
# Modify the file 00_setup.py to define input/output file paths on your system
# The information in 00_setup.py will be used across notebooks
from importlib.machinery import SourceFileLoader
setup = SourceFileLoader("setup", "./00_setup.py").load_module()

# %% [markdown]
# # XGBoost, NAICS Embeddings from Unsupervised GNN (including target as feature)
# Retry an XGBoost model but use the NAICS embeddings generated by an unsupervised GNN (base features plus target)

# %% [markdown]
# *This script takes about 5 minutes on my MacBook Air*

# %%
import pandas as pd
import numpy as np
import xgboost as xgb
import warnings
import matplotlib.pyplot as plt
import pickle

# %%
from pathlib import Path

# %%
import sklearn as sk
from sklearn.model_selection import RandomizedSearchCV
from sklearn.inspection import permutation_importance, partial_dependence
from scikitplot.metrics import plot_lift_curve

# %%
from sba_gnn.sba_gnn import sg_plot

# %% [markdown]
# ## Import Processed Datasets

# %%
sba_loans = pd.read_parquet(Path(setup.temp_path).joinpath('01_DATA_transformed.parquet'))

# %%
embed_df = pd.read_parquet(Path(setup.temp_path).joinpath('47_DATA_embeddings.parquet'))

# %%
sba_loans = sba_loans.merge(embed_df.rename(columns={'NAICS_orig':'NAICS'}),
                            on='NAICS', how='left')

# %%
train_df = sba_loans[sba_loans['dset'] == 'train'].copy()
test_df = sba_loans[sba_loans['dset'] == 'test']
val_df = sba_loans[sba_loans['dset'] == 'val']

# %%
train_df.shape
# Out:
# (425594, 59)

# %%
train_df.drop_duplicates('LoanNr_ChkDgt').shape
# Out:
# (425594, 59)

# %% [markdown]
# #### Set the predictor features.  Inlcude the mean-encoded NAICS

# %%
predictor_features = setup.predictor_features + [c for c in embed_df.columns if c.startswith('emb')]
print(predictor_features)
# Out:
# ['NoEmp', 'CreateJob', 'LowDoc', 'DisbursementGross', 'new_business', 'urban_flag', 'franchise_flag', 'emb_000', 'emb_001', 'emb_002', 'emb_003', 'emb_004', 'emb_005', 'emb_006', 'emb_007']

# %%
train_df[predictor_features].describe()
# Out:
#                NoEmp      CreateJob         LowDoc  DisbursementGross  \
# count  425594.000000  425594.000000  422477.000000       4.255940e+05
# mean        9.758920       2.172277       0.097807       1.949280e+05
# std        63.011166      15.140139       0.297053       2.994808e+05
# min         0.000000       0.000000       0.000000       4.000000e+03
# 25%         2.000000       0.000000       0.000000       3.600000e+04
# 50%         4.000000       0.000000       0.000000       9.000000e+04
# 75%         9.000000       2.000000       0.000000       2.157000e+05
# max      9992.000000    5621.000000       1.000000       1.144632e+07
#
#         new_business     urban_flag  franchise_flag        emb_000  \
# count  425050.000000  342255.000000   425594.000000  425594.000000
# mean        0.279906       0.814930        0.050858       0.237190
# std         0.448953       0.388355        0.219709       0.013434
# min         0.000000       0.000000        0.000000       0.223118
# 25%         0.000000       1.000000        0.000000       0.225822
# 50%         0.000000       1.000000        0.000000       0.232626
# 75%         1.000000       1.000000        0.000000       0.244384
# max         1.000000       1.000000        1.000000       0.281355
#
#              emb_001        emb_002        emb_003        emb_004  \
# count  425594.000000  425594.000000  425594.000000  425594.000000
# mean        0.372581       0.326656       0.023973       0.454891
# std         0.021103       0.018501       0.001358       0.025763
# min         0.350476       0.307276       0.022551       0.427834
# 25%         0.354724       0.311000       0.022824       0.433089
# 50%         0.365411       0.320370       0.023512       0.446133
# 75%         0.383882       0.336563       0.024700       0.468701
# max         0.441957       0.387480       0.028437       0.539640
#
#              emb_005        emb_006        emb_007
# count  425594.000000  425594.000000  425594.000000
# mean       -0.332815      -0.088461       0.019633
# std         0.259963       0.368086       0.408707
# min        -0.536836      -0.533924      -0.470716
# 25%        -0.451707      -0.428908      -0.409944
# 50%        -0.433871      -0.240175      -0.106543
# 75%        -0.410508       0.337943       0.438877
# max         0.473365       0.472787       0.531838

# %%
tcorr = train_df[predictor_features + ['target']].corr()
tcorr.to_csv(Path(setup.temp_path).joinpath('54_REPORT_correlations.csv'))
tcorr[tcorr.index == 'target']
# Out:
#            NoEmp  CreateJob    LowDoc  DisbursementGross  new_business  \
# target -0.027838   -0.00954 -0.076836          -0.122857      0.014277
#
#         urban_flag  franchise_flag   emb_000   emb_001   emb_002   emb_003  \
# target    0.054391       -0.011047 -0.017274 -0.017274 -0.017274 -0.017274
#
#          emb_004   emb_005   emb_006   emb_007  target
# target -0.017231 -0.114972 -0.086333 -0.150865     1.0

# %%
with open(Path(setup.temp_path).joinpath('54_DATA_features_predict.pkl'), 'wb') as fout:
    pickle.dump(predictor_features, fout)

# %% [markdown]
# ## Model Fit

# %%
best_params_df = pd.read_csv(Path(setup.temp_path).joinpath('03_REPORT_fit_parameter_selected.csv'))
best_params = best_params_df.to_dict(orient='records')[0]
best_params
# Out:
# {'subsample': 0.8,
#  'scale_pos_weight': 1.0,
#  'reg_lambda': 0.01,
#  'reg_alpha': 0.001,
#  'min_child_weight': 50,
#  'max_depth': 8,
#  'learning_rate': 0.1,
#  'gamma': 2}

# %% [markdown]
# ##### Fit using pre-determined parameters

# %%
xgb_params = dict(best_params, 
                   **{'objective':"binary:logistic", 'n_estimators':setup.xgb_n_estimators})

# %%
xgb_model = xgb.XGBClassifier(objective="binary:logistic",
                             n_estimators = setup.xgb_n_estimators)

# %%
xgb_model = xgb_model.set_params(**xgb_params)

# %%
xgb_model.fit(train_df[predictor_features], train_df['target'],
              eval_set = [(train_df[predictor_features], train_df['target']),
                         (val_df[predictor_features], val_df['target'])])
# Out:
# [0]	validation_0-logloss:0.49952	validation_1-logloss:0.50238
# [1]	validation_0-logloss:0.49302	validation_1-logloss:0.49587
# [2]	validation_0-logloss:0.48753	validation_1-logloss:0.49035
# [3]	validation_0-logloss:0.48269	validation_1-logloss:0.48553
# [4]	validation_0-logloss:0.47848	validation_1-logloss:0.48135
# [5]	validation_0-logloss:0.47494	validation_1-logloss:0.47783
# [6]	validation_0-logloss:0.47197	validation_1-logloss:0.47487
# [7]	validation_0-logloss:0.46929	validation_1-logloss:0.47220
# [8]	validation_0-logloss:0.46694	validation_1-logloss:0.46990
# [9]	validation_0-logloss:0.46489	validation_1-logloss:0.46790
# [10]	validation_0-logloss:0.46295	validation_1-logloss:0.46602
# [11]	validation_0-logloss:0.46140	validation_1-logloss:0.46453
# [12]	validation_0-logloss:0.46005	validation_1-logloss:0.46323
# [13]	validation_0-logloss:0.45883	validation_1-logloss:0.46209
# [14]	validation_0-logloss:0.45766	validation_1-logloss:0.46098
# [15]	validation_0-logloss:0.45665	validation_1-logloss:0.46002
# [16]	validation_0-logloss:0.45577	validation_1-logloss:0.45916
# [17]	validation_0-logloss:0.45501	validation_1-logloss:0.45843
# [18]	validation_0-logloss:0.45426	validation_1-logloss:0.45776
# [19]	validation_0-logloss:0.45370	validation_1-logloss:0.45723
# [20]	validation_0-logloss:0.45312	validation_1-logloss:0.45672
# [21]	validation_0-logloss:0.45258	validation_1-logloss:0.45625
# [22]	validation_0-logloss:0.45211	validation_1-logloss:0.45583
# [23]	validation_0-logloss:0.45149	validation_1-logloss:0.45525
# [24]	validation_0-logloss:0.45104	validation_1-logloss:0.45490
# [25]	validation_0-logloss:0.45057	validation_1-logloss:0.45451
# [26]	validation_0-logloss:0.45017	validation_1-logloss:0.45422
# [27]	validation_0-logloss:0.44982	validation_1-logloss:0.45396
# [28]	validation_0-logloss:0.44954	validation_1-logloss:0.45374
# [29]	validation_0-logloss:0.44928	validation_1-logloss:0.45355
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=2, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.1, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=8, max_leaves=None,
#               min_child_weight=50, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=30, n_jobs=None,
#               num_parallel_tree=None, random_state=None, ...)

# %% [markdown]
# ##### Save the model

# %%
xgb_model.save_model(Path(setup.temp_path).joinpath('523MODEL_xgboost.json'))

# %%
with open(Path(setup.temp_path).joinpath('54_MODEL_xgboost.pkl'), 'wb') as po:
    pickle.dump(xgb_model, po)

# %% [markdown]
# ## Probability Predictions

# %%
pred_df = pd.concat([sba_loans[['LoanNr_ChkDgt', 'dset', 'target', 'dset_naics_holdout']].reset_index(),
                     pd.DataFrame({'predict_prob':
                                   xgb_model.predict_proba(sba_loans[predictor_features])[:,1]})],
                    axis=1) \
    .set_index('index')

# %%
pred_df.groupby('target')['predict_prob'].agg(['mean', 'std', 'min', 'max', 'median'])
# Out:
#             mean       std       min       max    median
# target
# 0       0.185854  0.109842  0.015306  0.618085  0.176717
# 1       0.276953  0.097328  0.015681  0.638463  0.286483

# %% [markdown]
# ## Decision Threshold
# Max f1, on training data

# %%
pred_train_df = pred_df[pred_df['dset'] == 'train']

# %%
thresh_tune_data = sg_plot.get_f1_frame(pred_train_df['target'], 
                                        pred_train_df['predict_prob'])

# %%
thresh_tune_data.to_csv(Path(setup.temp_path).joinpath('54_REPORT_thresh_tune.csv'), index=False)

# %%
thresh_head = thresh_tune_data.sort_values('f1', ascending=False).head(2)
best_thresh = thresh_head['thresh'].iloc[0]
print(best_thresh)
thresh_head
# Out:
# 0.24
#     thresh        f1
# 12    0.24  0.449890
# 11    0.22  0.448334

# %% [markdown]
# ##### Apply decision threshold
# All datasets

# %%
pred_df['predict_bin'] = np.where(pred_df['predict_prob'] >= best_thresh, 1, 0)

# %%
pred_df['predict_bin'].value_counts()
# Out:
# predict_bin
# 0    397002
# 1    291079
# Name: count, dtype: int64

# %%
pred_df.to_parquet(Path(setup.temp_path).joinpath('54_DATA_combined_predictions.parquet'))

# %% [markdown]
# ## Metrics

# %%
metrics_dset_df = pred_df.groupby('dset') \
    .apply(lambda x: sg_plot.dset_metrics(x.target, x.predict_bin, x.predict_prob)) \
    .reset_index()
metrics_test_df = pred_df[pred_df['dset'] == 'test'] \
    .groupby(['dset', 'dset_naics_holdout']) \
    .apply(lambda x: sg_plot.dset_metrics(x.target, x.predict_bin, x.predict_prob)) \
    .reset_index()
metrics_df = pd.concat([metrics_dset_df, metrics_test_df])
metrics_df.to_csv(Path(setup.temp_path).joinpath('54_REPORT_metrics.csv'), index=True)
metrics_df
# Out:
#     dset  accuracy_score  f1_score  precision_score  recall_score  \
# 0   test        0.652141  0.441771         0.325680      0.686465
# 1  train        0.655477  0.449890         0.332884      0.693730
# 2    val        0.654652  0.450404         0.334647      0.688595
# 0   test        0.654032  0.446303         0.331100      0.684454
# 1   test        0.646289  0.427586         0.309151      0.693119
#
#    average_precision_score  roc_auc_score  dset_naics_holdout
# 0                 0.373375       0.726543                 NaN
# 1                 0.382085       0.730930                 NaN
# 2                 0.376023       0.727021                 NaN
# 0                 0.379757       0.727275                 0.0
# 1                 0.353878       0.724106                 1.0

# %% [markdown]
# ## Lift
# Test data

# %%
pred_test_df = pred_df[pred_df['dset'] == 'test']

# %%
plot_lift_curve(pred_test_df['target'], 
                pd.concat([1-pred_test_df['predict_prob'], pred_test_df['predict_prob']], axis=1), 
                title='Lift Curve', ax=None, figsize=(4,3), 
                title_fontsize='large', text_fontsize='medium')
plt.gca().legend(loc='upper right')
plt.gcf().savefig(Path(setup.temp_path).joinpath('54_PLOT_lift_curve.png'),bbox_inches='tight')

# %% [markdown]
# ## Feature Importance

# %% [markdown]
# ##### XGBoost gain

# %%
feat_impgain = pd.DataFrame(xgb_model.get_booster().get_score(importance_type='gain'),
                                     index=['importance']).T \
    .sort_values('importance', ascending=False)

# %%
feat_impgain.to_csv(Path(setup.temp_path).joinpath('54_REPORT_importance_gain.csv'), index=True)

# %%
feat_impgain.head()
# Out:
#                    importance
# urban_flag         946.624695
# LowDoc             163.332779
# DisbursementGross   95.538963
# new_business        32.463657
# CreateJob           26.388105

# %%
feat_impgain.plot(kind='barh', legend=None)
plt.gca().invert_yaxis()
plt.xlabel('gain importance')
plt.gcf().savefig(Path(setup.temp_path).joinpath('54_PLOT_importance_gain.png'))

# %% [markdown]
# ##### Permutation Importance

# %%
perm_importance = permutation_importance(xgb_model, 
                                         train_df[predictor_features],  train_df['target'],
                                         n_repeats=30, scoring = 'average_precision')

# %%
perm_importance_df = pd.DataFrame({'features':predictor_features,
                                   'importance': perm_importance['importances_mean']}) 
perm_importance_df['abs_importance'] = np.abs(perm_importance_df['importance'])
perm_importance_df = perm_importance_df.sort_values('abs_importance', ascending=False)

# %%
perm_importance_df.head(5)
# Out:
#              features  importance  abs_importance
# 3   DisbursementGross    0.082780        0.082780
# 5          urban_flag    0.041241        0.041241
# 1           CreateJob    0.029527        0.029527
# 14            emb_007    0.024977        0.024977
# 12            emb_005    0.020857        0.020857

# %%
perm_importance_df \
    .to_csv(Path(setup.temp_path).joinpath('54_DATA_importance_perturb.csv'),
            index=False)

# %%
perm_importance_df.head(10).plot(kind='barh', x='features', y='importance', legend=None)
plt.gca().invert_yaxis()
plt.xlabel('permutation importance')
plt.ylabel(None)
plt.gcf().savefig(Path(setup.temp_path).joinpath('54_PLOT_importance_perturb.png'))

# %% [markdown]
# ## PDP Plot - Embeddings

# %%
def get_pdp(feature):
    results = partial_dependence(xgb_model, train_df[predictor_features], [feature])
    return pd.DataFrame({'grid_values':results["grid_values"][0],
                       'pdp':results["average"][0]})

# %%
emb_feat = [c for c in embed_df.columns if c.startswith('emb')]
pdp_res = pd.concat([get_pdp(c) for c in emb_feat], axis=0, keys=emb_feat)

# %%
pdp_res = pdp_res.reset_index(level=0) \
    .rename(columns={'level_0':'feature'})
pdp_res.head()
# Out:
#    feature  grid_values       pdp
# 0  emb_000     0.223496  0.220342
# 1  emb_000     0.223969  0.207817
# 2  emb_000     0.224443  0.205966
# 3  emb_000     0.224916  0.206436
# 4  emb_000     0.225390  0.205650

# %%
nrow = int(np.ceil(len(emb_feat) / 4))
ncol = 4 if len(emb_feat) % 4 == 0 else 5

# %%
fig, ax = plt.subplots(nrow, ncol, figsize = (10, 10), sharex = False, sharey=True)
for i in range(len(emb_feat)):
    this_row = int(np.floor(i / 4))
    this_col = int(i % 4)
    this_pdp = pdp_res[pdp_res['feature'] == emb_feat[i]]
    #print(f'i:{i}, row:{this_row}, col:{this_col}, feat:{emb_feat[i]}')
    this_pdp.plot(x='grid_values', y='pdp', label=emb_feat[i], ax=ax[this_row, this_col])
    #ax[this_row, this_col].set_title(emb_feat[i])
    ax[this_row, this_col].legend(loc='upper left')
    ax[this_row, this_col].set_xlabel(None)
plt.tight_layout()
plt.show()
fig.savefig(Path(setup.temp_path).joinpath('54_PLOT_pdp_naics_embeddings.png'),
               bbox_inches='tight')
