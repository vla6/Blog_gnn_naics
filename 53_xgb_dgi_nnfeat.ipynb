# %%
# Modify the file 00_setup.py to define input/output file paths on your system
# The information in 00_setup.py will be used across notebooks
from importlib.machinery import SourceFileLoader
setup = SourceFileLoader("setup", "./00_setup.py").load_module()

# %% [markdown]
# # XGBoost, NAICS Embeddings from DGI (NN features)
# Retry an XGBoost model but use the NAICS embeddings generated by an unsupervised GNN (NN features)

# %% [markdown]
# *This script takes about 5 minutes on my MacBook Air*

# %%
import pandas as pd
import numpy as np
import xgboost as xgb
import warnings
import matplotlib.pyplot as plt
import pickle

# %%
from pathlib import Path

# %%
import sklearn as sk
from sklearn.model_selection import RandomizedSearchCV
from sklearn.inspection import permutation_importance, partial_dependence
from scikitplot.metrics import plot_lift_curve

# %%
from sba_gnn.sba_gnn import sg_plot

# %% [markdown]
# ## Import Processed Datasets

# %%
sba_loans = pd.read_parquet(Path(setup.temp_path).joinpath('01_DATA_transformed.parquet'))

# %%
embed_df = pd.read_parquet(Path(setup.temp_path).joinpath('35_DATA_embeddings.parquet'))

# %%
sba_loans = sba_loans.merge(embed_df.rename(columns={'NAICS_orig':'NAICS'}),
                            on='NAICS', how='left')

# %%
train_df = sba_loans[sba_loans['dset'] == 'train'].copy()
test_df = sba_loans[sba_loans['dset'] == 'test']
val_df = sba_loans[sba_loans['dset'] == 'val']

# %%
train_df.shape
# Out:
# (425594, 59)

# %%
train_df.drop_duplicates('LoanNr_ChkDgt').shape
# Out:
# (425594, 59)

# %% [markdown]
# #### Set the predictor features.  Base features plus DGI embedding (DGI built using NN features)

# %%
predictor_features = setup.predictor_features + [c for c in embed_df.columns if c.startswith('emb')]
print(predictor_features)
# Out:
# ['NoEmp', 'CreateJob', 'LowDoc', 'DisbursementGross', 'new_business', 'urban_flag', 'franchise_flag', 'emb_000', 'emb_001', 'emb_002', 'emb_003', 'emb_004', 'emb_005', 'emb_006', 'emb_007']

# %%
train_df[predictor_features].describe()
# Out:
#                NoEmp      CreateJob         LowDoc  DisbursementGross  \
# count  425594.000000  425594.000000  422477.000000       4.255940e+05
# mean        9.758920       2.172277       0.097807       1.949280e+05
# std        63.011166      15.140139       0.297053       2.994808e+05
# min         0.000000       0.000000       0.000000       4.000000e+03
# 25%         2.000000       0.000000       0.000000       3.600000e+04
# 50%         4.000000       0.000000       0.000000       9.000000e+04
# 75%         9.000000       2.000000       0.000000       2.157000e+05
# max      9992.000000    5621.000000       1.000000       1.144632e+07
#
#         new_business     urban_flag  franchise_flag        emb_000  \
# count  425050.000000  342255.000000   425594.000000  425594.000000
# mean        0.279906       0.814930        0.050858       0.198300
# std         0.448953       0.388355        0.219709       0.008570
# min         0.000000       0.000000        0.000000       0.184379
# 25%         0.000000       1.000000        0.000000       0.191824
# 50%         0.000000       1.000000        0.000000       0.198256
# 75%         1.000000       1.000000        0.000000       0.203442
# max         1.000000       1.000000        1.000000       0.254550
#
#              emb_001        emb_002        emb_003        emb_004  \
# count  425594.000000  425594.000000  425594.000000  425594.000000
# mean        0.328440       0.353337       0.345679      -0.145308
# std         0.014194       0.015270       0.014939       0.349167
# min         0.305382       0.328532       0.321412      -0.544822
# 25%         0.317713       0.341797       0.334389      -0.427845
# 50%         0.328365       0.353257       0.345601      -0.404144
# 75%         0.336955       0.362497       0.354641       0.302332
# max         0.421604       0.453564       0.443734       0.444497
#
#              emb_005        emb_006        emb_007
# count  425594.000000  425594.000000  425594.000000
# mean        0.340394       0.065453      -0.080915
# std         0.245816       0.362363       0.382452
# min        -0.452811      -0.463996      -0.494427
# 25%         0.409143      -0.325133      -0.421932
# 50%         0.427633       0.089314      -0.354272
# 75%         0.447054       0.425957       0.386298
# max         0.553274       0.514102       0.484738

# %%
tcorr = train_df[predictor_features + ['target']].corr()
tcorr.to_csv(Path(setup.temp_path).joinpath('53_REPORT_correlations.csv'))
tcorr[tcorr.index == 'target']
# Out:
#            NoEmp  CreateJob    LowDoc  DisbursementGross  new_business  \
# target -0.027838   -0.00954 -0.076836          -0.122857      0.014277
#
#         urban_flag  franchise_flag   emb_000   emb_001   emb_002   emb_003  \
# target    0.054391       -0.011047  0.065289  0.065289  0.065289  0.065289
#
#          emb_004   emb_005   emb_006   emb_007  target
# target -0.122667  0.106839 -0.115939  0.173681     1.0

# %%
with open(Path(setup.temp_path).joinpath('53_DATA_features_predict.pkl'), 'wb') as fout:
    pickle.dump(predictor_features, fout)

# %% [markdown]
# ## Model Fit

# %%
best_params_df = pd.read_csv(Path(setup.temp_path).joinpath('03_REPORT_fit_parameter_selected.csv'))
best_params = best_params_df.to_dict(orient='records')[0]
best_params
# Out:
# {'subsample': 0.8,
#  'scale_pos_weight': 1.0,
#  'reg_lambda': 0.01,
#  'reg_alpha': 0.001,
#  'min_child_weight': 50,
#  'max_depth': 8,
#  'learning_rate': 0.1,
#  'gamma': 2}

# %% [markdown]
# ##### Fit using pre-determined parameters

# %%
xgb_params = dict(best_params, 
                   **{'objective':"binary:logistic", 'n_estimators':setup.xgb_n_estimators})

# %%
xgb_model = xgb.XGBClassifier(objective="binary:logistic",
                             n_estimators = setup.xgb_n_estimators)

# %%
xgb_model = xgb_model.set_params(**xgb_params)

# %%
xgb_model.fit(train_df[predictor_features], train_df['target'],
              eval_set = [(train_df[predictor_features], train_df['target']),
                         (val_df[predictor_features], val_df['target'])])
# Out:
# [0]	validation_0-logloss:0.49957	validation_1-logloss:0.50240
# [1]	validation_0-logloss:0.49297	validation_1-logloss:0.49579
# [2]	validation_0-logloss:0.48741	validation_1-logloss:0.49020
# [3]	validation_0-logloss:0.48261	validation_1-logloss:0.48542
# [4]	validation_0-logloss:0.47839	validation_1-logloss:0.48125
# [5]	validation_0-logloss:0.47473	validation_1-logloss:0.47760
# [6]	validation_0-logloss:0.47161	validation_1-logloss:0.47453
# [7]	validation_0-logloss:0.46884	validation_1-logloss:0.47181
# [8]	validation_0-logloss:0.46649	validation_1-logloss:0.46948
# [9]	validation_0-logloss:0.46442	validation_1-logloss:0.46744
# [10]	validation_0-logloss:0.46255	validation_1-logloss:0.46563
# [11]	validation_0-logloss:0.46096	validation_1-logloss:0.46409
# [12]	validation_0-logloss:0.45964	validation_1-logloss:0.46279
# [13]	validation_0-logloss:0.45850	validation_1-logloss:0.46169
# [14]	validation_0-logloss:0.45733	validation_1-logloss:0.46058
# [15]	validation_0-logloss:0.45643	validation_1-logloss:0.45970
# [16]	validation_0-logloss:0.45556	validation_1-logloss:0.45884
# [17]	validation_0-logloss:0.45490	validation_1-logloss:0.45822
# [18]	validation_0-logloss:0.45407	validation_1-logloss:0.45748
# [19]	validation_0-logloss:0.45350	validation_1-logloss:0.45692
# [20]	validation_0-logloss:0.45282	validation_1-logloss:0.45631
# [21]	validation_0-logloss:0.45225	validation_1-logloss:0.45584
# [22]	validation_0-logloss:0.45168	validation_1-logloss:0.45539
# [23]	validation_0-logloss:0.45126	validation_1-logloss:0.45501
# [24]	validation_0-logloss:0.45085	validation_1-logloss:0.45462
# [25]	validation_0-logloss:0.45057	validation_1-logloss:0.45437
# [26]	validation_0-logloss:0.45008	validation_1-logloss:0.45402
# [27]	validation_0-logloss:0.44971	validation_1-logloss:0.45371
# [28]	validation_0-logloss:0.44945	validation_1-logloss:0.45348
# [29]	validation_0-logloss:0.44924	validation_1-logloss:0.45330
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=2, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.1, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=8, max_leaves=None,
#               min_child_weight=50, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=30, n_jobs=None,
#               num_parallel_tree=None, random_state=None, ...)

# %% [markdown]
# ##### Save the model

# %%
xgb_model.save_model(Path(setup.temp_path).joinpath('53_MODEL_xgboost.json'))

# %%
with open(Path(setup.temp_path).joinpath('53_MODEL_xgboost.pkl'), 'wb') as po:
    pickle.dump(xgb_model, po)

# %% [markdown]
# ## Probability Predictions

# %%
pred_df = pd.concat([sba_loans[['LoanNr_ChkDgt', 'dset', 'target', 'dset_naics_holdout']].reset_index(),
                     pd.DataFrame({'predict_prob':
                                   xgb_model.predict_proba(sba_loans[predictor_features])[:,1]})],
                    axis=1) \
    .set_index('index')

# %%
pred_df.groupby('target')['predict_prob'].agg(['mean', 'std', 'min', 'max', 'median'])
# Out:
#             mean       std       min       max    median
# target
# 0       0.185726  0.109715  0.015687  0.661197  0.179292
# 1       0.277082  0.098564  0.016100  0.664103  0.285875

# %% [markdown]
# ## Decision Threshold
# Max f1, on training data

# %%
pred_train_df = pred_df[pred_df['dset'] == 'train']

# %%
thresh_tune_data = sg_plot.get_f1_frame(pred_train_df['target'], 
                                        pred_train_df['predict_prob'])

# %%
thresh_tune_data.to_csv(Path(setup.temp_path).joinpath('53_REPORT_thresh_tune.csv'), index=False)

# %%
thresh_head = thresh_tune_data.sort_values('f1', ascending=False).head(2)
best_thresh = thresh_head['thresh'].iloc[0]
print(best_thresh)
thresh_head
# Out:
# 0.24
#     thresh        f1
# 12    0.24  0.449845
# 11    0.22  0.448375

# %% [markdown]
# ##### Apply decision threshold
# All datasets

# %%
pred_df['predict_bin'] = np.where(pred_df['predict_prob'] >= best_thresh, 1, 0)

# %%
pred_df['predict_bin'].value_counts()
# Out:
# predict_bin
# 0    402067
# 1    286014
# Name: count, dtype: int64

# %%
pred_df.to_parquet(Path(setup.temp_path).joinpath('53_DATA_combined_predictions.parquet'))

# %% [markdown]
# ## Metrics

# %%
metrics_dset_df = pred_df.groupby('dset') \
    .apply(lambda x: sg_plot.dset_metrics(x.target, x.predict_bin, x.predict_prob)) \
    .reset_index()
metrics_test_df = pred_df[pred_df['dset'] == 'test'] \
    .groupby(['dset', 'dset_naics_holdout']) \
    .apply(lambda x: sg_plot.dset_metrics(x.target, x.predict_bin, x.predict_prob)) \
    .reset_index()
metrics_df = pd.concat([metrics_dset_df, metrics_test_df])
metrics_df.to_csv(Path(setup.temp_path).joinpath('53_REPORT_metrics.csv'), index=True)
metrics_df
# Out:
#     dset  accuracy_score  f1_score  precision_score  recall_score  \
# 0   test        0.656428  0.441711         0.327592      0.677839
# 1  train        0.659427  0.449845         0.334727      0.685654
# 2    val        0.658087  0.449399         0.335841      0.678982
# 0   test        0.657319  0.446401         0.332687      0.678218
# 1   test        0.653672  0.426840         0.311761      0.676586
#
#    average_precision_score  roc_auc_score  dset_naics_holdout
# 0                 0.371760       0.725845                 NaN
# 1                 0.383325       0.731047                 NaN
# 2                 0.379515       0.727631                 NaN
# 0                 0.380244       0.726961                 0.0
# 1                 0.344679       0.721780                 1.0

# %% [markdown]
# ## Lift
# Test data

# %%
pred_test_df = pred_df[pred_df['dset'] == 'test']

# %%
plot_lift_curve(pred_test_df['target'], 
                pd.concat([1-pred_test_df['predict_prob'], pred_test_df['predict_prob']], axis=1), 
                title='Lift Curve', ax=None, figsize=(4,3), 
                title_fontsize='large', text_fontsize='medium')
plt.gca().legend(loc='upper right')
plt.gcf().savefig(Path(setup.temp_path).joinpath('53_PLOT_lift_curve.png'),bbox_inches='tight')

# %% [markdown]
# ## Feature Importance

# %% [markdown]
# ##### XGBoost gain

# %%
feat_impgain = pd.DataFrame(xgb_model.get_booster().get_score(importance_type='gain'),
                                     index=['importance']).T \
    .sort_values('importance', ascending=False)

# %%
feat_impgain.to_csv(Path(setup.temp_path).joinpath('53_REPORT_importance_gain.csv'), index=True)

# %%
feat_impgain.head()
# Out:
#                    importance
# urban_flag         921.558105
# LowDoc             162.778961
# DisbursementGross  102.434280
# emb_007             35.969406
# new_business        31.291773

# %%
feat_impgain.plot(kind='barh', legend=None)
plt.gca().invert_yaxis()
plt.xlabel('gain importance')
plt.gcf().savefig(Path(setup.temp_path).joinpath('53_PLOT_importance_gain.png'))

# %% [markdown]
# ##### Permutation Importance

# %%
perm_importance = permutation_importance(xgb_model, 
                                         train_df[predictor_features],  train_df['target'],
                                         n_repeats=30, scoring = 'average_precision')

# %%
perm_importance_df = pd.DataFrame({'features':predictor_features,
                                   'importance': perm_importance['importances_mean']}) 
perm_importance_df['abs_importance'] = np.abs(perm_importance_df['importance'])
perm_importance_df = perm_importance_df.sort_values('abs_importance', ascending=False)

# %%
perm_importance_df.head(5)
# Out:
#              features  importance  abs_importance
# 3   DisbursementGross    0.076518        0.076518
# 14            emb_007    0.040183        0.040183
# 5          urban_flag    0.040094        0.040094
# 1           CreateJob    0.026209        0.026209
# 2              LowDoc    0.014722        0.014722

# %%
perm_importance_df \
    .to_csv(Path(setup.temp_path).joinpath('53_DATA_importance_perturb.csv'),
            index=False)

# %%
perm_importance_df.head(10).plot(kind='barh', x='features', y='importance', legend=None)
plt.gca().invert_yaxis()
plt.xlabel('permutation importance')
plt.ylabel(None)
plt.gcf().savefig(Path(setup.temp_path).joinpath('53_PLOT_importance_perturb.png'))

# %% [markdown]
# ## PDP Plot - Embeddings

# %%
def get_pdp(feature):
    results = partial_dependence(xgb_model, train_df[predictor_features], [feature])
    return pd.DataFrame({'grid_values':results["grid_values"][0],
                       'pdp':results["average"][0]})

# %%
emb_feat = [c for c in embed_df.columns if c.startswith('emb')]
pdp_res = pd.concat([get_pdp(c) for c in emb_feat], axis=0, keys=emb_feat)

# %%
pdp_res = pdp_res.reset_index(level=0) \
    .rename(columns={'level_0':'feature'})
pdp_res.head()
# Out:
#    feature  grid_values       pdp
# 0  emb_000     0.186270  0.215573
# 1  emb_000     0.186552  0.215637
# 2  emb_000     0.186833  0.213553
# 3  emb_000     0.187115  0.213553
# 4  emb_000     0.187397  0.210908

# %%
nrow = int(np.ceil(len(emb_feat) / 4))
ncol = 4 if len(emb_feat) % 4 == 0 else 5

# %%
fig, ax = plt.subplots(nrow, ncol, figsize = (10, 10), sharex = False, sharey=True)
for i in range(len(emb_feat)):
    this_row = int(np.floor(i / 4))
    this_col = int(i % 4)
    this_pdp = pdp_res[pdp_res['feature'] == emb_feat[i]]
    #print(f'i:{i}, row:{this_row}, col:{this_col}, feat:{emb_feat[i]}')
    this_pdp.plot(x='grid_values', y='pdp', label=emb_feat[i], ax=ax[this_row, this_col])
    #ax[this_row, this_col].set_title(emb_feat[i])
    ax[this_row, this_col].legend(loc='upper left')
    ax[this_row, this_col].set_xlabel(None)
plt.tight_layout()
plt.show()
fig.savefig(Path(setup.temp_path).joinpath('53_PLOT_pdp_naics_embeddings.png'),
               bbox_inches='tight')
