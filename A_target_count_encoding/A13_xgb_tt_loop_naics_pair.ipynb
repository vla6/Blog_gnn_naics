# %%
# Modify the file A00_setup.  Note the working directory is changed
import os
os.chdir(os.getcwd().rsplit(os.path.sep + 'code')[0] + os.path.sep + 'code')
from importlib.machinery import SourceFileLoader
setup = SourceFileLoader("setup", "./A_target_count_encoding/A00_setup.py").load_module()
os.getcwd()
# Out:
# '/Users/valeriecarey/Documents/projects/2023_10_blog_gnn_sba/code'

# %% [markdown]
# # XGBoost, Target+Count Encoding: Vary hierarchy (code pairs)
# Do an alternative hierarchical blending, NAICS + one additional code

# %% [markdown]
# *This script takes about 5 minutes on my MacBook Air*

# %%
import pandas as pd
import numpy as np
import xgboost as xgb
import warnings
import matplotlib.pyplot as plt
import pickle

# %%
from pathlib import Path

# %%
import sklearn as sk
from sklearn.model_selection import RandomizedSearchCV
from sklearn.inspection import permutation_importance, partial_dependence
from scikitplot.metrics import plot_lift_curve

# %%
from sba_gnn.sba_gnn import sg_plot, sg_target_count_encoder
from sba_gnn.sba_gnn.sg_target_thresh_encoder import TargetThreshEncoder

# %% [markdown]
# ## Import Processed Datasets

# %%
sba_loans = pd.read_parquet(Path(setup.parent_path).joinpath('01_DATA_transformed.parquet'))

# %%
best_params_df = pd.read_csv(Path(setup.parent_path).joinpath('03_REPORT_fit_parameter_selected.csv'))
best_params = best_params_df.to_dict(orient='records')[0]
best_params
# Out:
# {'subsample': 0.8,
#  'scale_pos_weight': 1.0,
#  'reg_lambda': 0.01,
#  'reg_alpha': 0.001,
#  'min_child_weight': 50,
#  'max_depth': 8,
#  'learning_rate': 0.1,
#  'gamma': 2}

# %%
xgb_params = dict(best_params, 
                   **{'objective':"binary:logistic", 'n_estimators':setup.xgb_n_estimators})

# %% [markdown]
# ##### Comparison metrics

# %%
metrics_base = pd.read_csv(Path(setup.parent_path).joinpath('16_REPORT_metrics.csv'))

# %%
# Group counts
naics_grp_counts = pd.read_csv(Path(setup.parent_path).joinpath('02_REPORT_naics_grp_stats_all.csv')) \
    [['level_0', 'count_grp']] \
    .drop_duplicates() \
    .set_axis(['naics_type', 'k'], axis=1)

# %%
# Regular, non-hierarchical target encoding, for a horizontal reference line
metrics_tenc = pd.read_csv(Path(setup.parent_path).joinpath('14_REPORT_metrics.csv'))

# %%
# Target+Count baseline
metrics_tcenc = pd.read_csv(Path(setup.temp_path).joinpath('A06_REPORT_metrics.csv'))

# %% [markdown]
# ## Function to get metrics

# %%
def get_metrics(data, threshold = setup.selected_lambda_k, enc_features = ['NAICS', 'NAICS_sector']):
    
    # Alternative encoding
    train_df = data[data['dset'] == 'train']
    enc_dict = {f:TargetThreshEncoder(threshold = threshold) for f in enc_features}
    [enc_dict[f].fit(train_df[f], train_df['target']) for f in enc_features]
    enc_val = pd.concat([enc_dict[f].transform(data[f]) for f in enc_features],
                    axis=1, keys=enc_features)
    enc_val.columns = [c[0] + '_' + c[1] for c in enc_val.columns]
    
    # Append to data
    data = pd.concat([data.drop(columns=enc_val.columns, errors='ignore'), enc_val], 
                      axis=1)
    train_df = data[data['dset'] == 'train']
    test_df = data[data['dset'] == 'test']
    val_df = data[data['dset'] == 'val']
    
    predictor_features = setup.predictor_features + list(enc_val.columns)

    # Model fit
    xgb_model = xgb.XGBClassifier(objective="binary:logistic",
                             n_estimators =  setup.xgb_n_estimators)
    xgb_model = xgb_model.set_params(**xgb_params)
    xgb_model.fit(train_df[predictor_features], train_df['target'],
              eval_set = [(train_df[predictor_features], train_df['target']),
                         (val_df[predictor_features], val_df['target'])])
    
    # Predict
    pred_df = pd.concat([data[['LoanNr_ChkDgt', 'dset', 'target', 'dset_naics_holdout']].reset_index(),
                     pd.DataFrame({'predict_prob':
                                   xgb_model.predict_proba(data[predictor_features])[:,1]})],
                    axis=1) \
    .set_index('index')
    
    # Decision threshold
    pred_train_df = pred_df[pred_df['dset'] == 'train']
    thresh_tune_data = sg_plot.get_f1_frame(pred_train_df['target'], 
                                        pred_train_df['predict_prob'])
    thresh_head = thresh_tune_data.sort_values('f1', ascending=False).head(2)
    best_thresh = thresh_head['thresh'].iloc[0]
    pred_df['predict_bin'] = np.where(pred_df['predict_prob'] >= best_thresh, 1, 0)
    
    # Metrics
    metrics_dset_df = pred_df.groupby('dset') \
        .apply(lambda x: sg_plot.dset_metrics(x.target, x.predict_bin, x.predict_prob)) \
        .reset_index()
    metrics_test_df = pred_df[pred_df['dset'] == 'test'] \
        .groupby(['dset', 'dset_naics_holdout']) \
        .apply(lambda x: sg_plot.dset_metrics(x.target, x.predict_bin, x.predict_prob)) \
        .reset_index()
    metrics_df = pd.concat([metrics_dset_df, metrics_test_df])
    
    return pred_df, metrics_df

# %% [markdown]
# ## Loop to get predictions, metrics

# %%
# Hierarchical encode from different levels
naics_sets = [['NAICS', 'NAICS_5'],
              ['NAICS', 'NAICS_4'],
              ['NAICS', 'NAICS_3'],
              ['NAICS', 'NAICS_sector']]

# %%
# %%capture
pred_df = pd.DataFrame()
metrics_df = pd.DataFrame()
for this_set in naics_sets:
    this_pred, this_met = get_metrics(sba_loans, enc_features=this_set)
    this_pred['naics_type'] = this_set[1]
    pred_df = pd.concat([pred_df, this_pred])
    this_met['naics_type'] = this_set[1]
    metrics_df = pd.concat([metrics_df, this_met])

# %%
metrics_df[metrics_df['dset_naics_holdout'] == 1]
# Out:
#    dset  accuracy_score  f1_score  precision_score  recall_score  \
# 1  test        0.694906  0.423136         0.322308      0.615769
# 1  test        0.689710  0.427132         0.321389      0.636579
# 1  test        0.699302  0.425167         0.325738      0.611962
# 1  test        0.686651  0.420250         0.316552      0.624989
#
#    average_precision_score  roc_auc_score  dset_naics_holdout    naics_type
# 1                 0.357337       0.734055                 1.0       NAICS_5
# 1                 0.363398       0.737638                 1.0       NAICS_4
# 1                 0.356097       0.735671                 1.0       NAICS_3
# 1                 0.349698       0.730974                 1.0  NAICS_sector

# %%
metrics_df[metrics_df['dset_naics_holdout'] == 0]
# Out:
#    dset  accuracy_score  f1_score  precision_score  recall_score  \
# 0  test        0.660136  0.450522         0.337498      0.677366
# 0  test        0.658723  0.451692         0.337322      0.683400
# 0  test        0.658991  0.451716         0.337463      0.682932
# 0  test        0.659558  0.450311         0.337119      0.677938
#
#    average_precision_score  roc_auc_score  dset_naics_holdout    naics_type
# 0                 0.385480       0.729348                 0.0       NAICS_5
# 0                 0.386199       0.729895                 0.0       NAICS_4
# 0                 0.386651       0.730187                 0.0       NAICS_3
# 0                 0.385606       0.729739                 0.0  NAICS_sector

# %%
pred_df.to_parquet(Path(setup.temp_path).joinpath('A13_DATA_combined_predictions.parquet'))
metrics_df.to_csv(Path(setup.temp_path).joinpath('A13_REPORT_metrics.csv'), index=True)

# %% [markdown]
# ## Comparison Plot

# %%
metrics_sum = metrics_df[~metrics_df['dset_naics_holdout'].isna()] \
    .merge(naics_grp_counts, on='naics_type', how='left')

# %%
metrics_base_sum = metrics_base[~metrics_base['dset_naics_holdout'].isna()] \
    .rename(columns={'start_naics':'naics_type'}) \
    .merge(naics_grp_counts, on='naics_type', how='left')

# %%
metrics_tcenc = metrics_tcenc[~metrics_tcenc['dset_naics_holdout'].isna()]  \
    .merge(naics_grp_counts, on='naics_type', how='left')

# %%
# Reference lines
hline_test = metrics_tenc[(metrics_tenc['dset_naics_holdout'] == 0) &
                          (metrics_tenc['c'] == setup.selected_lambda_k)] \
    ['average_precision_score'].iloc[0]
hline_ho = metrics_tenc[(metrics_tenc['dset_naics_holdout'] == 1) &
                          (metrics_tenc['c'] == setup.selected_lambda_k)] \
    ['average_precision_score'].iloc[0]
print(f'Regular target encoding test result: {hline_test}; holdout {hline_ho}')
# Out:
# Regular target encoding test result: 0.382950251407698; holdout 0.346336505844941

# %%
# Tick labels
label_k = sorted(metrics_sum['k'].drop_duplicates().astype('int').to_list())
label_str = ['sector', 'subsector', 'industry grp', 'industry']
labels = [f'k={label_k[i]}\n({label_str[i]})' for i in range(len(label_k))]
labels
# Out:
# ['k=20\n(sector)',
#  'k=106\n(subsector)',
#  'k=354\n(industry grp)',
#  'k=834\n(industry)']

# %%
fig, ax = plt.subplots()
metrics_base_sum[metrics_base_sum['dset_naics_holdout'] == 0] \
    .plot(x='k', y='average_precision_score', logx=True, ax=ax, 
          label='Hierarchichal Blend',color='darkslateblue', style='v-')
metrics_tcenc[metrics_tcenc['dset_naics_holdout'] == 0] \
    .plot(x='k', y='average_precision_score', logx=True, ax=ax, 
          label='Target+Count',color='darkorange', style='+-')
metrics_sum[metrics_sum['dset_naics_holdout'] == 0] \
    .plot(x='k', y='average_precision_score', logx=True, ax=ax, 
          label='Target-Thresh',color='violet', style='P-')
ax.set_ylabel('PR-AUC')
ax.set_xlabel('Group Count (k)')
fig.suptitle('Test Dataset')
ax.set_title('Encodings use groups at or above level')
plt.axhline(y=hline_test, color='darkgray')
ax.set_xticks(label_k)
ax.set_xticklabels(labels)
fig.savefig(Path(setup.temp_path).joinpath('A13_PLOT_compare_base_reg.png'),
            bbox_inches='tight')

# %%
fig, ax = plt.subplots()
metrics_base_sum[metrics_base_sum['dset_naics_holdout'] == 1] \
    .plot(x='k', y='average_precision_score', logx=True, ax=ax, 
          label='Hierarchichal Blend',color='darkslateblue', style='v-')
metrics_tcenc[metrics_tcenc['dset_naics_holdout'] == 1] \
    .plot(x='k', y='average_precision_score', logx=True, ax=ax, 
          label='Target+Count',color='darkorange', style='+-')
metrics_sum[metrics_sum['dset_naics_holdout'] == 1] \
    .plot(x='k', y='average_precision_score', logx=True, ax=ax, 
          label='Target-Thresh',color='violet', style='P-')
ax.set_ylabel('PR-AUC')
ax.set_xlabel('Group Count (k)')
fig.suptitle('Holdout NAICS Dataset')
ax.set_title('Encodings use groups at or above level')
plt.axhline(y=hline_ho, color='darkgray')
ax.set_xticks(label_k)
ax.set_xticklabels(labels)
fig.savefig(Path(setup.temp_path).joinpath('A13_PLOT_compare_base_ho_all.png'),
            bbox_inches='tight')
