# %%
# Modify the file 00_setup.py to define input/output file paths on your system
# The information in 00_setup.py will be used across notebooks
from importlib.machinery import SourceFileLoader
setup = SourceFileLoader("setup", "./00_setup.py").load_module()

# %% [markdown]
# # XGBoost, with NAICS embeddings from neural network
# Retry an XGBoost model but use the NAICS embeddings generated by the standard Neural Network (script 12)

# %% [markdown]
# *This script takes about 5 minutes on my MacBook Air*

# %%
import pandas as pd
import numpy as np
import xgboost as xgb
import warnings
import matplotlib.pyplot as plt
import pickle

# %%
from pathlib import Path

# %%
import sklearn as sk
from sklearn.model_selection import RandomizedSearchCV
from sklearn.inspection import permutation_importance, partial_dependence
from scikitplot.metrics import plot_lift_curve

# %%
from sba_gnn.sba_gnn import sg_plot

# %% [markdown]
# ## Import Processed Datasets

# %%
sba_loans = pd.read_parquet(Path(setup.temp_path).joinpath('01_DATA_transformed.parquet'))

# %%
embed_df = pd.read_parquet(Path(setup.temp_path).joinpath('12_DATA_embeddings.parquet'))

# %%
sba_loans = sba_loans.merge(embed_df.drop(columns='NAICS').rename(columns={'NAICS_orig':'NAICS'}),
                            on='NAICS', how='left')

# %%
train_df = sba_loans[sba_loans['dset'] == 'train'].copy()
test_df = sba_loans[sba_loans['dset'] == 'test']
val_df = sba_loans[sba_loans['dset'] == 'val']

# %%
train_df.shape
# Out:
# (436120, 63)

# %%
train_df.drop_duplicates('LoanNr_ChkDgt').shape
# Out:
# (436120, 63)

# %% [markdown]
# #### Set the predictor features.  Inlcude the mean-encoded NAICS

# %%
predictor_features = setup.predictor_features + [c for c in embed_df.columns if c.startswith('emb')]
print(predictor_features)
# Out:
# ['NoEmp', 'CreateJob', 'LowDoc', 'DisbursementGross', 'new_business', 'urban_flag', 'franchise_flag', 'emb_000', 'emb_001', 'emb_002', 'emb_003', 'emb_004', 'emb_005', 'emb_006', 'emb_007']

# %%
train_df[predictor_features].describe()
# Out:
#                NoEmp      CreateJob         LowDoc  DisbursementGross  \
# count  436120.000000  436120.000000  432893.000000       4.361200e+05
# mean        9.723145       2.164835       0.097777       1.944230e+05
# std        61.690596      11.315009       0.297013       2.989452e+05
# min         0.000000       0.000000       0.000000       4.000000e+03
# 25%         2.000000       0.000000       0.000000       3.572600e+04
# 50%         4.000000       0.000000       0.000000       9.000000e+04
# 75%         9.000000       2.000000       0.000000       2.148528e+05
# max      9999.000000    3000.000000       1.000000       1.144632e+07
#
#         new_business     urban_flag  franchise_flag        emb_000  \
# count  435584.000000  351624.000000   436120.000000  436120.000000
# mean        0.281016       0.815075        0.052733      -0.585633
# std         0.449496       0.388237        0.223501       0.386456
# min         0.000000       0.000000        0.000000      -2.087339
# 25%         0.000000       1.000000        0.000000      -0.831431
# 50%         0.000000       1.000000        0.000000      -0.531347
# 75%         1.000000       1.000000        0.000000      -0.315007
# max         1.000000       1.000000        1.000000       0.781830
#
#              emb_001        emb_002        emb_003        emb_004  \
# count  436120.000000  436120.000000  436120.000000  436120.000000
# mean        0.451574      -0.698704      -0.015907       0.421343
# std         0.305599       0.556357       0.288149       0.436095
# min        -0.651716      -3.256534      -1.252174      -0.805879
# 25%         0.253556      -1.003245      -0.197584       0.101998
# 50%         0.400741      -0.577144       0.031905       0.313033
# 75%         0.607230      -0.315982       0.192145       0.690880
# max         1.574973       0.895160       1.099739       2.002111
#
#              emb_005        emb_006        emb_007
# count  436120.000000  436120.000000  436120.000000
# mean        0.437973      -0.274624       0.564667
# std         0.475219       0.316496       0.356534
# min        -1.016769      -1.732012      -0.731778
# 25%         0.080065      -0.456661       0.307569
# 50%         0.336897      -0.236192       0.542542
# 75%         0.682859      -0.034849       0.781731
# max         2.271168       0.735580       1.698727

# %%
tcorr = train_df[predictor_features + ['target']].corr()
tcorr.to_csv(Path(setup.temp_path).joinpath('40_REPORT_correlations.csv'))
tcorr[tcorr.index == 'target']
# Out:
#            NoEmp  CreateJob    LowDoc  DisbursementGross  new_business  \
# target -0.027403  -0.010002 -0.079523          -0.120788      0.013878
#
#         urban_flag  franchise_flag   emb_000   emb_001   emb_002   emb_003  \
# target    0.053785       -0.012731  0.194354 -0.191719  0.189865  0.065819
#
#          emb_004   emb_005   emb_006   emb_007  target
# target -0.183718 -0.168655  0.153575 -0.204808     1.0

# %%
with open(Path(setup.temp_path).joinpath('40_DATA_features_predict.pkl'), 'wb') as fout:
    pickle.dump(predictor_features, fout)

# %% [markdown]
# ## Model Fit

# %%
best_params_df = pd.read_csv(Path(setup.temp_path).joinpath('03_REPORT_fit_parameter_selected.csv'))
best_params = best_params_df.to_dict(orient='records')[0]
best_params
# Out:
# {'subsample': 0.8,
#  'scale_pos_weight': 1.0,
#  'reg_lambda': 0.01,
#  'reg_alpha': 0.001,
#  'min_child_weight': 50,
#  'max_depth': 8,
#  'learning_rate': 0.1,
#  'gamma': 2}

# %% [markdown]
# ##### Fit using pre-determined parameters

# %%
xgb_params = dict(best_params, 
                   **{'objective':"binary:logistic", 'n_estimators':setup.xgb_n_estimators})

# %%
xgb_model = xgb.XGBClassifier(objective="binary:logistic",
                             n_estimators = setup.xgb_n_estimators)

# %%
xgb_model = xgb_model.set_params(**xgb_params)

# %%
xgb_model.fit(train_df[predictor_features], train_df['target'],
              eval_set = [(train_df[predictor_features], train_df['target']),
                         (val_df[predictor_features], val_df['target'])])
# Out:
# [0]	validation_0-logloss:0.50017	validation_1-logloss:0.50393
# [1]	validation_0-logloss:0.49245	validation_1-logloss:0.49658
# [2]	validation_0-logloss:0.48596	validation_1-logloss:0.49045
# [3]	validation_0-logloss:0.48021	validation_1-logloss:0.48503
# [4]	validation_0-logloss:0.47546	validation_1-logloss:0.48059
# [5]	validation_0-logloss:0.47135	validation_1-logloss:0.47680
# [6]	validation_0-logloss:0.46777	validation_1-logloss:0.47346
# [7]	validation_0-logloss:0.46475	validation_1-logloss:0.47073
# [8]	validation_0-logloss:0.46208	validation_1-logloss:0.46826
# [9]	validation_0-logloss:0.45977	validation_1-logloss:0.46620
# [10]	validation_0-logloss:0.45769	validation_1-logloss:0.46439
# [11]	validation_0-logloss:0.45594	validation_1-logloss:0.46294
# [12]	validation_0-logloss:0.45445	validation_1-logloss:0.46166
# [13]	validation_0-logloss:0.45312	validation_1-logloss:0.46058
# [14]	validation_0-logloss:0.45188	validation_1-logloss:0.45954
# [15]	validation_0-logloss:0.45083	validation_1-logloss:0.45869
# [16]	validation_0-logloss:0.44992	validation_1-logloss:0.45803
# [17]	validation_0-logloss:0.44905	validation_1-logloss:0.45738
# [18]	validation_0-logloss:0.44833	validation_1-logloss:0.45687
# [19]	validation_0-logloss:0.44759	validation_1-logloss:0.45633
# [20]	validation_0-logloss:0.44702	validation_1-logloss:0.45590
# [21]	validation_0-logloss:0.44641	validation_1-logloss:0.45547
# [22]	validation_0-logloss:0.44598	validation_1-logloss:0.45519
# [23]	validation_0-logloss:0.44548	validation_1-logloss:0.45485
# [24]	validation_0-logloss:0.44509	validation_1-logloss:0.45460
# [25]	validation_0-logloss:0.44480	validation_1-logloss:0.45446
# [26]	validation_0-logloss:0.44443	validation_1-logloss:0.45428
# [27]	validation_0-logloss:0.44405	validation_1-logloss:0.45406
# [28]	validation_0-logloss:0.44369	validation_1-logloss:0.45385
# [29]	validation_0-logloss:0.44339	validation_1-logloss:0.45366
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=2, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.1, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=8, max_leaves=None,
#               min_child_weight=50, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=30, n_jobs=None,
#               num_parallel_tree=None, random_state=None, ...)

# %% [markdown]
# ##### Save the model

# %%
xgb_model.save_model(Path(setup.temp_path).joinpath('40_MODEL_xgboost.json'))

# %%
with open(Path(setup.temp_path).joinpath('40_MODEL_xgboost.pkl'), 'wb') as po:
    pickle.dump(xgb_model, po)

# %% [markdown]
# ## Probability Predictions

# %%
pred_df = pd.concat([sba_loans[['LoanNr_ChkDgt', 'dset', 'target', 'dset_naics_holdout']].reset_index(),
                     pd.DataFrame({'predict_prob':
                                   xgb_model.predict_proba(sba_loans[predictor_features])[:,1]})],
                    axis=1) \
    .set_index('index')

# %%
pred_df.groupby('target')['predict_prob'].agg(['mean', 'std', 'min', 'max', 'median'])
# Out:
#             mean       std       min       max    median
# target
# 0       0.192896  0.122530  0.016993  0.713803  0.175846
# 1       0.297611  0.115478  0.021347  0.711359  0.303176

# %% [markdown]
# ## Decision Threshold
# Max f1, on training data

# %%
pred_train_df = pred_df[pred_df['dset'] == 'train']

# %%
thresh_tune_data = sg_plot.get_f1_frame(pred_train_df['target'], 
                                        pred_train_df['predict_prob'])

# %%
thresh_tune_data.to_csv(Path(setup.temp_path).joinpath('40_REPORT_thresh_tune.csv'), index=False)

# %%
thresh_head = thresh_tune_data.sort_values('f1', ascending=False).head(2)
best_thresh = thresh_head['thresh'].iloc[0]
print(best_thresh)
thresh_head
# Out:
# 0.24
#     thresh        f1
# 12    0.24  0.462841
# 11    0.22  0.461425

# %% [markdown]
# ##### Apply decision threshold
# All datasets

# %%
pred_df['predict_bin'] = np.where(pred_df['predict_prob'] >= best_thresh, 1, 0)

# %%
pred_df['predict_bin'].value_counts()
# Out:
# predict_bin
# 0    391605
# 1    296476
# Name: count, dtype: int64

# %%
pred_df.to_parquet(Path(setup.temp_path).joinpath('40_DATA_combined_predictions.parquet'))

# %% [markdown]
# ## Metrics

# %%
metrics_dset_df = pred_df.groupby('dset') \
    .apply(lambda x: sg_plot.dset_metrics(x.target, x.predict_bin, x.predict_prob)) \
    .reset_index()
metrics_test_df = pred_df[pred_df['dset'] == 'test'] \
    .groupby(['dset', 'dset_naics_holdout']) \
    .apply(lambda x: sg_plot.dset_metrics(x.target, x.predict_bin, x.predict_prob)) \
    .reset_index()
metrics_df = pd.concat([metrics_dset_df, metrics_test_df])
metrics_df.to_csv(Path(setup.temp_path).joinpath('40_REPORT_metrics.csv'), index=True)
metrics_df
# Out:
#     dset  accuracy_score  f1_score  precision_score  recall_score  \
# 0   test        0.594314  0.422173         0.292752      0.756700
# 1  train        0.670611  0.462841         0.347346      0.693403
# 2    val        0.663781  0.453044         0.341934      0.671119
# 0   test        0.663004  0.451821         0.339507      0.675181
# 1   test        0.495634  0.390534         0.250208      0.889265
#
#    average_precision_score  roc_auc_score  dset_naics_holdout
# 0                 0.344016       0.707204                 NaN
# 1                 0.406096       0.744805                 NaN
# 2                 0.390688       0.729915                 NaN
# 0                 0.386461       0.730490                 0.0
# 1                 0.332862       0.717261                 1.0

# %% [markdown]
# ## Lift
# Test data

# %%
pred_test_df = pred_df[pred_df['dset'] == 'test']

# %%
plot_lift_curve(pred_test_df['target'], 
                pd.concat([1-pred_test_df['predict_prob'], pred_test_df['predict_prob']], axis=1), 
                title='Lift Curve', ax=None, figsize=(4,3), 
                title_fontsize='large', text_fontsize='medium')
plt.gca().legend(loc='upper right')
plt.gcf().savefig(Path(setup.temp_path).joinpath('40_PLOT_lift_curve.png'),bbox_inches='tight')

# %% [markdown]
# ## Feature Importance

# %% [markdown]
# ##### XGBoost gain

# %%
feat_impgain = pd.DataFrame(xgb_model.get_booster().get_score(importance_type='gain'),
                                     index=['importance']).T \
    .sort_values('importance', ascending=False)

# %%
feat_impgain.to_csv(Path(setup.temp_path).joinpath('40_REPORT_importance_gain.csv'), index=True)

# %%
feat_impgain.head()
# Out:
#                    importance
# urban_flag         833.882812
# emb_007            202.099258
# LowDoc             101.328522
# DisbursementGross   63.173817
# emb_002             37.222313

# %%
feat_impgain.plot(kind='barh', legend=None)
plt.gca().invert_yaxis()
plt.xlabel('gain importance')
plt.gcf().savefig(Path(setup.temp_path).joinpath('40_PLOT_importance_gain.png'))

# %% [markdown]
# ##### Permutation Importance

# %%
perm_importance = permutation_importance(xgb_model, 
                                         train_df[predictor_features],  train_df['target'],
                                         n_repeats=30, scoring = 'average_precision')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 perm_importance = permutation_importance(xgb_model,
#       2                                          train_df[predictor_features],  train_df['target'],
#       3                                          n_repeats=30, scoring = 'average_precision')
#
# File ~/miniconda3/envs/tf_p38/lib/python3.8/site-packages/sklearn/utils/_param_validation.py:214, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     208 try:
#     209     with config_context(
#     210         skip_parameter_validation=(
#     211             prefer_skip_nested_validation or global_skip_validation
#     212         )
#     213     ):
# --> 214         return func(*args, **kwargs)
#     215 except InvalidParameterError as e:
#     216     # When the function is just a wrapper around an estimator, we allow
#     217     # the function to delegate validation to the estimator, but we replace
#     218     # the name of the estimator by the name of the function in the error
#     219     # message to avoid confusion.
#     220     msg = re.sub(
#     221         r"parameter of \w+ must be",
#     222         f"parameter of {func.__qualname__} must be",
#     223         str(e),
#     224     )
#
# File ~/miniconda3/envs/tf_p38/lib/python3.8/site-packages/sklearn/inspection/_permutation_importance.py:289, in permutation_importance(estimator, X, y, scoring, n_repeats, n_jobs, random_state, sample_weight, max_samples)
#     285     scorer = _MultimetricScorer(scorers=scorers_dict)
#     287 baseline_score = _weights_scorer(scorer, estimator, X, y, sample_weight)
# --> 289 scores = Parallel(n_jobs=n_jobs)(
#     290     delayed(_calculate_permutation_scores)(
#     291         estimator,
#     292         X,
#     293         y,
#     294         sample_weight,
#     295         col_idx,
#     296         random_seed,
#     297         n_repeats,
#     298         scorer,
#     299         max_samples,
#     300     )
#     301     for col_idx in range(X.shape[1])
#     302 )
#     304 if isinstance(baseline_score, dict):
#     305     return {
#     306         name: _create_importances_bunch(
#     307             baseline_score[name],
#    (...)
#     311         for name in baseline_score
#     312     }
#
# File ~/miniconda3/envs/tf_p38/lib/python3.8/site-packages/sklearn/utils/parallel.py:65, in Parallel.__call__(self, iterable)
#      60 config = get_config()
#      61 iterable_with_config = (
#      62     (_with_config(delayed_func, config), args, kwargs)
#      63     for delayed_func, args, kwargs in iterable
#      64 )
# ---> 65 return super().__call__(iterable_with_config)
#
# File ~/miniconda3/envs/tf_p38/lib/python3.8/site-packages/joblib/parallel.py:1863, in Parallel.__call__(self, iterable)
#    1861     output = self._get_sequential_output(iterable)
#    1862     next(output)
# -> 1863     return output if self.return_generator else list(output)
#    1865 # Let's create an ID that uniquely identifies the current call. If the
#    1866 # call is interrupted early and that the same instance is immediately
#    1867 # re-used, this id will be used to prevent workers that were
#    1868 # concurrently finalizing a task from the previous call to run the
#    1869 # callback.
#    1870 with self._lock:
#
# File ~/miniconda3/envs/tf_p38/lib/python3.8/site-packages/joblib/parallel.py:1792, in Parallel._get_sequential_output(self, iterable)
#    1790 self.n_dispatched_batches += 1
#    1791 self.n_dispatched_tasks += 1
# -> 1792 res = func(*args, **kwargs)
#    1793 self.n_completed_tasks += 1
#    1794 self.print_progress()
#
# File ~/miniconda3/envs/tf_p38/lib/python3.8/site-packages/sklearn/utils/parallel.py:127, in _FuncWrapper.__call__(self, *args, **kwargs)
#     125     config = {}
#     126 with config_context(**config):
# --> 127     return self.function(*args, **kwargs)
#
# File ~/miniconda3/envs/tf_p38/lib/python3.8/site-packages/sklearn/inspection/_permutation_importance.py:70, in _calculate_permutation_scores(estimator, X, y, sample_weight, col_idx, random_state, n_repeats, scorer, max_samples)
#      68     else:
#      69         X_permuted[:, col_idx] = X_permuted[shuffling_idx, col_idx]
# ---> 70     scores.append(_weights_scorer(scorer, estimator, X_permuted, y, sample_weight))
#      72 if isinstance(scores[0], dict):
#      73     scores = _aggregate_score_dicts(scores)
#
# File ~/miniconda3/envs/tf_p38/lib/python3.8/site-packages/sklearn/inspection/_permutation_importance.py:25, in _weights_scorer(scorer, estimator, X, y, sample_weight)
#      23 if sample_weight is not None:
#      24     return scorer(estimator, X, y, sample_weight=sample_weight)
# ---> 25 return scorer(estimator, X, y)
#
# File ~/miniconda3/envs/tf_p38/lib/python3.8/site-packages/sklearn/metrics/_scorer.py:266, in _BaseScorer.__call__(self, estimator, X, y_true, sample_weight, **kwargs)
#     263 if sample_weight is not None:
#     264     _kwargs["sample_weight"] = sample_weight
# --> 266 return self._score(partial(_cached_call, None), estimator, X, y_true, **_kwargs)
#
# File ~/miniconda3/envs/tf_p38/lib/python3.8/site-packages/sklearn/metrics/_scorer.py:471, in _ThresholdScorer._score(self, method_caller, clf, X, y, **kwargs)
#     468             y_pred = np.vstack([p[:, -1] for p in y_pred]).T
#     470 scoring_kwargs = {**self._kwargs, **kwargs}
# --> 471 return self._sign * self._score_func(y, y_pred, **scoring_kwargs)
#
# File ~/miniconda3/envs/tf_p38/lib/python3.8/site-packages/sklearn/utils/_param_validation.py:187, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     185 global_skip_validation = get_config()["skip_parameter_validation"]
#     186 if global_skip_validation:
# --> 187     return func(*args, **kwargs)
#     189 func_sig = signature(func)
#     191 # Map *args/**kwargs to the function signature
#
# File ~/miniconda3/envs/tf_p38/lib/python3.8/site-packages/sklearn/metrics/_ranking.py:268, in average_precision_score(y_true, y_score, average, pos_label, sample_weight)
#     263     y_true = label_binarize(y_true, classes=present_labels)
#     265 average_precision = partial(
#     266     _binary_uninterpolated_average_precision, pos_label=pos_label
#     267 )
# --> 268 return _average_binary_score(
#     269     average_precision, y_true, y_score, average, sample_weight=sample_weight
#     270 )
#
# File ~/miniconda3/envs/tf_p38/lib/python3.8/site-packages/sklearn/metrics/_base.py:75, in _average_binary_score(binary_metric, y_true, y_score, average, sample_weight)
#      72     raise ValueError("{0} format is not supported".format(y_type))
#      74 if y_type == "binary":
# ---> 75     return binary_metric(y_true, y_score, sample_weight=sample_weight)
#      77 check_consistent_length(y_true, y_score, sample_weight)
#      78 y_true = check_array(y_true)
#
# File ~/miniconda3/envs/tf_p38/lib/python3.8/site-packages/sklearn/metrics/_ranking.py:230, in average_precision_score.<locals>._binary_uninterpolated_average_precision(y_true, y_score, pos_label, sample_weight)
#     227 def _binary_uninterpolated_average_precision(
#     228     y_true, y_score, pos_label=1, sample_weight=None
#     229 ):
# --> 230     precision, recall, _ = precision_recall_curve(
#     231         y_true, y_score, pos_label=pos_label, sample_weight=sample_weight
#     232     )
#     233     # Return the step function integral
#     234     # The following works because the last entry of precision is
#     235     # guaranteed to be 1, as returned by precision_recall_curve
#     236     return -np.sum(np.diff(recall) * np.array(precision)[:-1])
#
# File ~/miniconda3/envs/tf_p38/lib/python3.8/site-packages/sklearn/utils/_param_validation.py:187, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     185 global_skip_validation = get_config()["skip_parameter_validation"]
#     186 if global_skip_validation:
# --> 187     return func(*args, **kwargs)
#     189 func_sig = signature(func)
#     191 # Map *args/**kwargs to the function signature
#
# File ~/miniconda3/envs/tf_p38/lib/python3.8/site-packages/sklearn/metrics/_ranking.py:952, in precision_recall_curve(y_true, probas_pred, pos_label, sample_weight, drop_intermediate)
#     852 @validate_params(
#     853     {
#     854         "y_true": ["array-like"],
#    (...)
#     863     y_true, probas_pred, *, pos_label=None, sample_weight=None, drop_intermediate=False
#     864 ):
#     865     """Compute precision-recall pairs for different probability thresholds.
#     866
#     867     Note: this implementation is restricted to the binary classification task.
#    (...)
#     950     array([0.1 , 0.35, 0.4 , 0.8 ])
#     951     """
# --> 952     fps, tps, thresholds = _binary_clf_curve(
#     953         y_true, probas_pred, pos_label=pos_label, sample_weight=sample_weight
#     954     )
#     956     if drop_intermediate and len(fps) > 2:
#     957         # Drop thresholds corresponding to points where true positives (tps)
#     958         # do not change from the previous or subsequent point. This will keep
#     959         # only the first and last point for each tps value. All points
#     960         # with the same tps value have the same recall and thus x coordinate.
#     961         # They appear as a vertical line on the plot.
#     962         optimal_idxs = np.where(
#     963             np.concatenate(
#     964                 [[True], np.logical_or(np.diff(tps[:-1]), np.diff(tps[1:])), [True]]
#     965             )
#     966         )[0]
#
# File ~/miniconda3/envs/tf_p38/lib/python3.8/site-packages/sklearn/metrics/_ranking.py:827, in _binary_clf_curve(y_true, y_score, pos_label, sample_weight)
#     824 y_true = y_true == pos_label
#     826 # sort scores and corresponding truth values
# --> 827 desc_score_indices = np.argsort(y_score, kind="mergesort")[::-1]
#     828 y_score = y_score[desc_score_indices]
#     829 y_true = y_true[desc_score_indices]
#
# File <__array_function__ internals>:200, in argsort(*args, **kwargs)
#
# File ~/miniconda3/envs/tf_p38/lib/python3.8/site-packages/numpy/core/fromnumeric.py:1146, in argsort(a, axis, kind, order)
#    1038 @array_function_dispatch(_argsort_dispatcher)
#    1039 def argsort(a, axis=-1, kind=None, order=None):
#    1040     """
#    1041     Returns the indices that would sort an array.
#    1042
#    (...)
#    1144
#    1145     """
# -> 1146     return _wrapfunc(a, 'argsort', axis=axis, kind=kind, order=order)
#
# File ~/miniconda3/envs/tf_p38/lib/python3.8/site-packages/numpy/core/fromnumeric.py:57, in _wrapfunc(obj, method, *args, **kwds)
#      54     return _wrapit(obj, method, *args, **kwds)
#      56 try:
# ---> 57     return bound(*args, **kwds)
#      58 except TypeError:
#      59     # A TypeError occurs if the object does have such a method in its
#      60     # class, but its signature is not identical to that of NumPy's. This
#    (...)
#      64     # Call _wrapit from within the except clause to ensure a potential
#      65     # exception has a traceback chain.
#      66     return _wrapit(obj, method, *args, **kwds)
#
# KeyboardInterrupt:

# %%
perm_importance_df = pd.DataFrame({'features':predictor_features,
                                   'importance': perm_importance['importances_mean']}) 
perm_importance_df['abs_importance'] = np.abs(perm_importance_df['importance'])
perm_importance_df = perm_importance_df.sort_values('abs_importance', ascending=False)

# %%
perm_importance_df.head(5)

# %%
perm_importance_df \
    .to_csv(Path(setup.temp_path).joinpath('40_DATA_importance_perturb.csv'),
            index=False)

# %%
perm_importance_df.head(10).plot(kind='barh', x='features', y='importance', legend=None)
plt.gca().invert_yaxis()
plt.xlabel('permutation importance')
plt.ylabel(None)
plt.gcf().savefig(Path(setup.temp_path).joinpath('40_PLOT_importance_perturb.png'))

# %% [markdown]
# ## PDP Plot - Embeddings

# %%
def get_pdp(feature):
    results = partial_dependence(xgb_model, train_df[predictor_features], [feature])
    return pd.DataFrame({'grid_values':results["grid_values"][0],
                       'pdp':results["average"][0]})

# %%
emb_feat = [c for c in embed_df.columns if c.startswith('emb')]
pdp_res = pd.concat([get_pdp(c) for c in emb_feat], axis=0, keys=emb_feat)

# %%
pdp_res = pdp_res.reset_index(level=0) \
    .rename(columns={'level_0':'feature'})
pdp_res.head()

# %%
nrow = int(np.ceil(len(emb_feat) / 2))
ncol = 2 if len(emb_feat) % 2 == 0 else 3

# %%
fig, ax = plt.subplots(nrow, ncol, figsize = (10, 8), sharex = False, sharey=True)
for i in range(len(emb_feat)):
    this_row = int(np.floor(i / 2))
    this_col = int(i % 2)
    this_pdp = pdp_res[pdp_res['feature'] == emb_feat[i]]
    #print(f'i:{i}, row:{this_row}, col:{this_col}, feat:{emb_feat[i]}')
    this_pdp.plot(x='grid_values', y='pdp', label=emb_feat[i], ax=ax[this_row, this_col])
    #ax[this_row, this_col].set_title(emb_feat[i])
    #ax[this_row, this_col].legend(loc='upper left')
    ax[this_row, this_col].set_xlabel(None)
plt.tight_layout()
plt.show()
fig.savefig(Path(setup.temp_path).joinpath('40_PLOT_pdp_naics_embeddings.png'),
               bbox_inches='tight')
