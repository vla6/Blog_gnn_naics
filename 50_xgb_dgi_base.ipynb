# %%
# Modify the file 00_setup.py to define input/output file paths on your system
# The information in 00_setup.py will be used across notebooks
from importlib.machinery import SourceFileLoader
setup = SourceFileLoader("setup", "./00_setup.py").load_module()

# %% [markdown]
# # XGBoost, NAICS Embeddings from DGI (Base Features)
# Retry an XGBoost model but use the NAICS embeddings generated by an unsupervised GNN (base features)

# %% [markdown]
# *This script takes about 5 minutes on my MacBook Air*

# %%
import pandas as pd
import numpy as np
import xgboost as xgb
import warnings
import matplotlib.pyplot as plt
import pickle

# %%
from pathlib import Path

# %%
import sklearn as sk
from sklearn.model_selection import RandomizedSearchCV
from sklearn.inspection import permutation_importance, partial_dependence
from scikitplot.metrics import plot_lift_curve

# %%
from sba_gnn.sba_gnn import sg_plot

# %% [markdown]
# ## Import Processed Datasets

# %%
sba_loans = pd.read_parquet(Path(setup.temp_path).joinpath('01_DATA_transformed.parquet'))

# %%
embed_df = pd.read_parquet(Path(setup.temp_path).joinpath('31_DATA_embeddings.parquet'))

# %%
sba_loans = sba_loans.merge(embed_df.rename(columns={'NAICS_orig':'NAICS'}),
                            on='NAICS', how='left')

# %%
train_df = sba_loans[sba_loans['dset'] == 'train'].copy()
test_df = sba_loans[sba_loans['dset'] == 'test']
val_df = sba_loans[sba_loans['dset'] == 'val']

# %%
train_df.shape
# Out:
# (425594, 59)

# %%
train_df.drop_duplicates('LoanNr_ChkDgt').shape
# Out:
# (425594, 59)

# %% [markdown]
# #### Set the predictor features.  Base features and DGI embeddings

# %%
predictor_features = setup.predictor_features + [c for c in embed_df.columns if c.startswith('emb')]
print(predictor_features)
# Out:
# ['NoEmp', 'CreateJob', 'LowDoc', 'DisbursementGross', 'new_business', 'urban_flag', 'franchise_flag', 'emb_000', 'emb_001', 'emb_002', 'emb_003', 'emb_004', 'emb_005', 'emb_006', 'emb_007']

# %%
train_df[predictor_features].describe()
# Out:
#                NoEmp      CreateJob         LowDoc  DisbursementGross  \
# count  425594.000000  425594.000000  422477.000000       4.255940e+05
# mean        9.758920       2.172277       0.097807       1.949280e+05
# std        63.011166      15.140139       0.297053       2.994808e+05
# min         0.000000       0.000000       0.000000       4.000000e+03
# 25%         2.000000       0.000000       0.000000       3.600000e+04
# 50%         4.000000       0.000000       0.000000       9.000000e+04
# 75%         9.000000       2.000000       0.000000       2.157000e+05
# max      9992.000000    5621.000000       1.000000       1.144632e+07
#
#         new_business     urban_flag  franchise_flag        emb_000  \
# count  425050.000000  342255.000000   425594.000000  425594.000000
# mean        0.279906       0.814930        0.050858       0.217481
# std         0.448953       0.388355        0.219709       0.015362
# min         0.000000       0.000000        0.000000       0.176932
# 25%         0.000000       1.000000        0.000000       0.205041
# 50%         0.000000       1.000000        0.000000       0.214777
# 75%         1.000000       1.000000        0.000000       0.230765
# max         1.000000       1.000000        1.000000       0.288991
#
#              emb_001        emb_002        emb_003        emb_004  \
# count  425594.000000  425594.000000  425594.000000  425594.000000
# mean        0.355059       0.278155       0.212673       0.320055
# std         0.025080       0.019648       0.015023       0.045252
# min         0.288858       0.226293       0.173020      -0.046765
# 25%         0.334749       0.262244       0.200507       0.287924
# 50%         0.350643       0.274696       0.210028       0.322547
# 75%         0.376746       0.295145       0.225663       0.355195
# max         0.471804       0.369614       0.282601       0.625767
#
#              emb_005        emb_006        emb_007
# count  425594.000000  425594.000000  425594.000000
# mean        0.116025       0.214134       0.398127
# std         0.359394       0.402929       0.297893
# min        -0.513121      -0.552224      -0.577290
# 25%        -0.244208      -0.237154       0.375205
# 50%         0.020032       0.428989       0.531214
# 75%         0.489364       0.536771       0.564770
# max         0.652722       0.684669       0.704332

# %%
tcorr = train_df[predictor_features + ['target']].corr()
tcorr.to_csv(Path(setup.temp_path).joinpath('50_REPORT_correlations.csv'))
tcorr[tcorr.index == 'target']
# Out:
#            NoEmp  CreateJob    LowDoc  DisbursementGross  new_business  \
# target -0.027838   -0.00954 -0.076836          -0.122857      0.014277
#
#         urban_flag  franchise_flag   emb_000   emb_001   emb_002   emb_003  \
# target    0.054391       -0.011047 -0.024161 -0.024161 -0.024161 -0.024161
#
#          emb_004   emb_005   emb_006   emb_007  target
# target -0.091144 -0.176263  0.118293  0.119273     1.0

# %%
with open(Path(setup.temp_path).joinpath('50_DATA_features_predict.pkl'), 'wb') as fout:
    pickle.dump(predictor_features, fout)

# %% [markdown]
# ## Model Fit

# %%
best_params_df = pd.read_csv(Path(setup.temp_path).joinpath('03_REPORT_fit_parameter_selected.csv'))
best_params = best_params_df.to_dict(orient='records')[0]
best_params
# Out:
# {'subsample': 0.8,
#  'scale_pos_weight': 1.0,
#  'reg_lambda': 0.01,
#  'reg_alpha': 0.001,
#  'min_child_weight': 50,
#  'max_depth': 8,
#  'learning_rate': 0.1,
#  'gamma': 2}

# %% [markdown]
# ##### Fit using pre-determined parameters

# %%
xgb_params = dict(best_params, 
                   **{'objective':"binary:logistic", 'n_estimators':setup.xgb_n_estimators})

# %%
xgb_model = xgb.XGBClassifier(objective="binary:logistic",
                             n_estimators = setup.xgb_n_estimators)

# %%
xgb_model = xgb_model.set_params(**xgb_params)

# %%
xgb_model.fit(train_df[predictor_features], train_df['target'],
              eval_set = [(train_df[predictor_features], train_df['target']),
                         (val_df[predictor_features], val_df['target'])])
# Out:
# [0]	validation_0-logloss:0.49937	validation_1-logloss:0.50222
# [1]	validation_0-logloss:0.49272	validation_1-logloss:0.49553
# [2]	validation_0-logloss:0.48715	validation_1-logloss:0.48993
# [3]	validation_0-logloss:0.48236	validation_1-logloss:0.48512
# [4]	validation_0-logloss:0.47813	validation_1-logloss:0.48090
# [5]	validation_0-logloss:0.47457	validation_1-logloss:0.47733
# [6]	validation_0-logloss:0.47132	validation_1-logloss:0.47415
# [7]	validation_0-logloss:0.46864	validation_1-logloss:0.47148
# [8]	validation_0-logloss:0.46622	validation_1-logloss:0.46913
# [9]	validation_0-logloss:0.46410	validation_1-logloss:0.46702
# [10]	validation_0-logloss:0.46232	validation_1-logloss:0.46530
# [11]	validation_0-logloss:0.46070	validation_1-logloss:0.46372
# [12]	validation_0-logloss:0.45925	validation_1-logloss:0.46232
# [13]	validation_0-logloss:0.45808	validation_1-logloss:0.46121
# [14]	validation_0-logloss:0.45690	validation_1-logloss:0.46010
# [15]	validation_0-logloss:0.45600	validation_1-logloss:0.45922
# [16]	validation_0-logloss:0.45510	validation_1-logloss:0.45841
# [17]	validation_0-logloss:0.45436	validation_1-logloss:0.45773
# [18]	validation_0-logloss:0.45358	validation_1-logloss:0.45704
# [19]	validation_0-logloss:0.45301	validation_1-logloss:0.45649
# [20]	validation_0-logloss:0.45241	validation_1-logloss:0.45599
# [21]	validation_0-logloss:0.45185	validation_1-logloss:0.45550
# [22]	validation_0-logloss:0.45140	validation_1-logloss:0.45514
# [23]	validation_0-logloss:0.45094	validation_1-logloss:0.45474
# [24]	validation_0-logloss:0.45058	validation_1-logloss:0.45447
# [25]	validation_0-logloss:0.45018	validation_1-logloss:0.45407
# [26]	validation_0-logloss:0.44978	validation_1-logloss:0.45375
# [27]	validation_0-logloss:0.44944	validation_1-logloss:0.45345
# [28]	validation_0-logloss:0.44915	validation_1-logloss:0.45321
# [29]	validation_0-logloss:0.44882	validation_1-logloss:0.45293
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=2, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.1, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=8, max_leaves=None,
#               min_child_weight=50, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=30, n_jobs=None,
#               num_parallel_tree=None, random_state=None, ...)

# %% [markdown]
# ##### Save the model

# %%
xgb_model.save_model(Path(setup.temp_path).joinpath('50_MODEL_xgboost.json'))

# %%
with open(Path(setup.temp_path).joinpath('50_MODEL_xgboost.pkl'), 'wb') as po:
    pickle.dump(xgb_model, po)

# %% [markdown]
# ## Probability Predictions

# %%
pred_df = pd.concat([sba_loans[['LoanNr_ChkDgt', 'dset', 'target', 'dset_naics_holdout']].reset_index(),
                     pd.DataFrame({'predict_prob':
                                   xgb_model.predict_proba(sba_loans[predictor_features])[:,1]})],
                    axis=1) \
    .set_index('index')

# %%
pred_df.groupby('target')['predict_prob'].agg(['mean', 'std', 'min', 'max', 'median'])
# Out:
#             mean       std       min       max    median
# target
# 0       0.185295  0.110312  0.015293  0.618584  0.177042
# 1       0.276956  0.097359  0.015293  0.634058  0.287715

# %% [markdown]
# ## Decision Threshold
# Max f1, on training data

# %%
pred_train_df = pred_df[pred_df['dset'] == 'train']

# %%
thresh_tune_data = sg_plot.get_f1_frame(pred_train_df['target'], 
                                        pred_train_df['predict_prob'])

# %%
thresh_tune_data.to_csv(Path(setup.temp_path).joinpath('50_REPORT_thresh_tune.csv'), index=False)

# %%
thresh_head = thresh_tune_data.sort_values('f1', ascending=False).head(2)
best_thresh = thresh_head['thresh'].iloc[0]
print(best_thresh)
thresh_head
# Out:
# 0.24
#     thresh        f1
# 12    0.24  0.450823
# 11    0.22  0.449355

# %% [markdown]
# ##### Apply decision threshold
# All datasets

# %%
pred_df['predict_bin'] = np.where(pred_df['predict_prob'] >= best_thresh, 1, 0)

# %%
pred_df['predict_bin'].value_counts()
# Out:
# predict_bin
# 0    401604
# 1    286477
# Name: count, dtype: int64

# %%
pred_df.to_parquet(Path(setup.temp_path).joinpath('50_DATA_combined_predictions.parquet'))

# %% [markdown]
# ## Metrics

# %%
metrics_dset_df = pred_df.groupby('dset') \
    .apply(lambda x: sg_plot.dset_metrics(x.target, x.predict_bin, x.predict_prob)) \
    .reset_index()
metrics_test_df = pred_df[pred_df['dset'] == 'test'] \
    .groupby(['dset', 'dset_naics_holdout']) \
    .apply(lambda x: sg_plot.dset_metrics(x.target, x.predict_bin, x.predict_prob)) \
    .reset_index()
metrics_df = pd.concat([metrics_dset_df, metrics_test_df])
metrics_df.to_csv(Path(setup.temp_path).joinpath('50_REPORT_metrics.csv'), index=True)
metrics_df
# Out:
#     dset  accuracy_score  f1_score  precision_score  recall_score  \
# 0   test        0.659638  0.440166         0.328387      0.667312
# 1  train        0.658543  0.450823         0.334742      0.690155
# 2    val        0.657873  0.451318         0.336591      0.684696
# 0   test        0.656446  0.445772         0.331990      0.678218
# 1   test        0.669518  0.421335         0.316192      0.631239
#
#    average_precision_score  roc_auc_score  dset_naics_holdout
# 0                 0.372106       0.726276                 NaN
# 1                 0.381314       0.731715                 NaN
# 2                 0.377010       0.728433                 NaN
# 0                 0.378729       0.727182                 0.0
# 1                 0.349985       0.722550                 1.0

# %% [markdown]
# ## Lift
# Test data

# %%
pred_test_df = pred_df[pred_df['dset'] == 'test']

# %%
plot_lift_curve(pred_test_df['target'], 
                pd.concat([1-pred_test_df['predict_prob'], pred_test_df['predict_prob']], axis=1), 
                title='Lift Curve', ax=None, figsize=(4,3), 
                title_fontsize='large', text_fontsize='medium')
plt.gca().legend(loc='upper right')
plt.gcf().savefig(Path(setup.temp_path).joinpath('50_PLOT_lift_curve.png'),bbox_inches='tight')

# %% [markdown]
# ## Feature Importance

# %% [markdown]
# ##### XGBoost gain

# %%
feat_impgain = pd.DataFrame(xgb_model.get_booster().get_score(importance_type='gain'),
                                     index=['importance']).T \
    .sort_values('importance', ascending=False)

# %%
feat_impgain.to_csv(Path(setup.temp_path).joinpath('50_REPORT_importance_gain.csv'), index=True)

# %%
feat_impgain.head()
# Out:
#                    importance
# urban_flag         698.323364
# LowDoc             192.338516
# DisbursementGross   99.805191
# emb_005             33.313858
# new_business        28.955580

# %%
feat_impgain.plot(kind='barh', legend=None)
plt.gca().invert_yaxis()
plt.xlabel('gain importance')
plt.gcf().savefig(Path(setup.temp_path).joinpath('50_PLOT_importance_gain.png'))

# %% [markdown]
# ##### Permutation Importance

# %%
perm_importance = permutation_importance(xgb_model, 
                                         train_df[predictor_features],  train_df['target'],
                                         n_repeats=30, scoring = 'average_precision')

# %%
perm_importance_df = pd.DataFrame({'features':predictor_features,
                                   'importance': perm_importance['importances_mean']}) 
perm_importance_df['abs_importance'] = np.abs(perm_importance_df['importance'])
perm_importance_df = perm_importance_df.sort_values('abs_importance', ascending=False)

# %%
perm_importance_df.head(5)
# Out:
#              features  importance  abs_importance
# 3   DisbursementGross    0.079547        0.079547
# 5          urban_flag    0.039678        0.039678
# 1           CreateJob    0.029544        0.029544
# 12            emb_005    0.024329        0.024329
# 2              LowDoc    0.014101        0.014101

# %%
perm_importance_df \
    .to_csv(Path(setup.temp_path).joinpath('50_DATA_importance_perturb.csv'),
            index=False)

# %%
perm_importance_df.head(10).plot(kind='barh', x='features', y='importance', legend=None)
plt.gca().invert_yaxis()
plt.xlabel('permutation importance')
plt.ylabel(None)
plt.gcf().savefig(Path(setup.temp_path).joinpath('50_PLOT_importance_perturb.png'))

# %% [markdown]
# ## PDP Plot - Embeddings

# %%
def get_pdp(feature):
    results = partial_dependence(xgb_model, train_df[predictor_features], [feature])
    return pd.DataFrame({'grid_values':results["grid_values"][0],
                       'pdp':results["average"][0]})

# %%
emb_feat = [c for c in embed_df.columns if c.startswith('emb')]
pdp_res = pd.concat([get_pdp(c) for c in emb_feat], axis=0, keys=emb_feat)

# %%
pdp_res = pdp_res.reset_index(level=0) \
    .rename(columns={'level_0':'feature'})
pdp_res.head()
# Out:
#    feature  grid_values       pdp
# 0  emb_000     0.194461  0.194071
# 1  emb_000     0.194951  0.194071
# 2  emb_000     0.195441  0.194100
# 3  emb_000     0.195930  0.194100
# 4  emb_000     0.196420  0.194084

# %%
nrow = int(np.ceil(len(emb_feat) / 4))
ncol = 4 if len(emb_feat) % 4 == 0 else 5

# %%
fig, ax = plt.subplots(nrow, ncol, figsize = (10, 10), sharex = False, sharey=True)
for i in range(len(emb_feat)):
    this_row = int(np.floor(i / 4))
    this_col = int(i % 4)
    this_pdp = pdp_res[pdp_res['feature'] == emb_feat[i]]
    #print(f'i:{i}, row:{this_row}, col:{this_col}, feat:{emb_feat[i]}')
    this_pdp.plot(x='grid_values', y='pdp', label=emb_feat[i], ax=ax[this_row, this_col])
    #ax[this_row, this_col].set_title(emb_feat[i])
    ax[this_row, this_col].legend(loc='upper left')
    ax[this_row, this_col].set_xlabel(None)
plt.tight_layout()
plt.show()
fig.savefig(Path(setup.temp_path).joinpath('50_PLOT_pdp_naics_embeddings.png'),
               bbox_inches='tight')
